# %%
import warnings
warnings.filterwarnings("ignore")

import keras_tuner as kt

# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras

#  Import and read the charity_data.csv.
import pandas as pd 
ekg_db = pd.read_csv("ptbxl_database.csv")
ekg_db.head(3)
# Out:
# 2024-02-28 22:07:04.805493: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#    ecg_id  patient_id   age  sex  height  weight  nurse  site     device  \
# 0       1     15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 1       2     13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 2       3     20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
#
#         recording_date  ... validated_by_human baseline_drift static_noise  \
# 0  1984-11-09 09:17:34  ...               True            NaN    , I-V1,
# 1  1984-11-14 12:55:37  ...               True            NaN          NaN
# 2  1984-11-15 12:49:10  ...               True            NaN          NaN
#
#   burst_noise electrodes_problems  extra_beats  pacemaker  strat_fold  \
# 0         NaN                 NaN          NaN        NaN           3
# 1         NaN                 NaN          NaN        NaN           2
# 2         NaN                 NaN          NaN        NaN           5
#
#                  filename_lr                filename_hr
# 0  records100/00000/00001_lr  records500/00000/00001_hr
# 1  records100/00000/00002_lr  records500/00000/00002_hr
# 2  records100/00000/00003_lr  records500/00000/00003_hr
#
# [3 rows x 28 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
ekg_db.drop(columns = ['patient_id', 'recording_date', 'report', 'filename_hr',
                      'filename_lr', 'strat_fold', 'pacemaker', 'extra_beats',
                      'electrodes_problems', 'burst_noise', 'static_noise', 
                      'baseline_drift', 'validated_by_human', 'initial_autogenerated_report',
                      'second_opinion','heart_axis',
                      'infarction_stadium1', 'infarction_stadium2', 'site',
                      'nurse'], inplace=True)
ekg_db
# Out:
#        ecg_id    age  sex  height  weight      device  \
# 0           1   56.0    1     NaN    63.0   CS-12   E
# 1           2   19.0    0     NaN    70.0   CS-12   E
# 2           3   37.0    1     NaN    69.0   CS-12   E
# 3           4   24.0    0     NaN    82.0   CS-12   E
# 4           5   19.0    1     NaN    70.0   CS-12   E
# ...       ...    ...  ...     ...     ...         ...
# 21794   21833   67.0    1     NaN     NaN  AT-60    3
# 21795   21834  300.0    0     NaN     NaN  AT-60    3
# 21796   21835   59.0    1     NaN     NaN  AT-60    3
# 21797   21836   64.0    1     NaN     NaN  AT-60    3
# 21798   21837   68.0    0     NaN     NaN  AT-60    3
#
#                                                scp_codes  validated_by
# 0               {'NORM': 100.0, 'LVOLT': 0.0, 'SR': 0.0}           NaN
# 1                           {'NORM': 80.0, 'SBRAD': 0.0}           NaN
# 2                             {'NORM': 100.0, 'SR': 0.0}           NaN
# 3                             {'NORM': 100.0, 'SR': 0.0}           NaN
# 4                             {'NORM': 100.0, 'SR': 0.0}           NaN
# ...                                                  ...           ...
# 21794  {'NDT': 100.0, 'PVC': 100.0, 'VCLVH': 0.0, 'ST...           1.0
# 21795           {'NORM': 100.0, 'ABQRS': 0.0, 'SR': 0.0}           1.0
# 21796                         {'ISCAS': 50.0, 'SR': 0.0}           1.0
# 21797                         {'NORM': 100.0, 'SR': 0.0}           1.0
# 21798                         {'NORM': 100.0, 'SR': 0.0}           1.0
#
# [21799 rows x 8 columns]

# %%
for i in range(len(ekg_db)):
       ekg_db["scp_codes"][i] = ekg_db["scp_codes"][i].split("'")[1]
     
ekg_db["scp_codes"]
# Out:
# 0         NORM
# 1         NORM
# 2         NORM
# 3         NORM
# 4         NORM
#          ...
# 21794      NDT
# 21795     NORM
# 21796    ISCAS
# 21797     NORM
# 21798     NORM
# Name: scp_codes, Length: 21799, dtype: object

# %%
ekg_dummies = pd.get_dummies(ekg_db)
ekg_dummies.head(3)
# Out:
#    ecg_id   age  sex  height  weight  validated_by  device_AT-6     6  \
# 0       1  56.0    1     NaN    63.0           NaN              False
# 1       2  19.0    0     NaN    70.0           NaN              False
# 2       3  37.0    1     NaN    69.0           NaN              False
#
#    device_AT-6 C  device_AT-6 C 5.0  device_AT-6 C 5.3  ...  scp_codes_PACE  \
# 0          False              False              False  ...           False
# 1          False              False              False  ...           False
# 2          False              False              False  ...           False
#
#    scp_codes_PMI  scp_codes_PSVT  scp_codes_PVC  scp_codes_RAO/RAE  \
# 0          False           False          False              False
# 1          False           False          False              False
# 2          False           False          False              False
#
#    scp_codes_RVH  scp_codes_SEHYP  scp_codes_SR  scp_codes_STACH  \
# 0          False            False         False            False
# 1          False            False         False            False
# 2          False            False         False            False
#
#    scp_codes_WPW
# 0          False
# 1          False
# 2          False
#
# [3 rows x 67 columns]

# %%
dummies_clean = ekg_dummies[['ecg_id','age', 'sex', 'height', 'weight', 'scp_codes_NORM']]
dummies_clean.head(3)
# Out:
#    ecg_id   age  sex  height  weight  scp_codes_NORM
# 0       1  56.0    1     NaN    63.0            True
# 1       2  19.0    0     NaN    70.0            True
# 2       3  37.0    1     NaN    69.0            True

# %%
dummies_clean = dummies_clean.dropna()
dummies_clean.head(3)
# Out:
#      ecg_id   age  sex  height  weight  scp_codes_NORM
# 100     101  48.0    1   172.0    72.0            True
# 115     116  49.0    1   174.0    74.0           False
# 135     136  52.0    0   167.0    72.0            True

# %%
# Split our preprocessed data into our features and target arrays
X = dummies_clean.drop('scp_codes_NORM', axis=1).values
y = dummies_clean['scp_codes_NORM'].values


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Get the input feature/ shape
X_train_scaled.shape
input_features = X_train_scaled.shape[1]

# %%
y = y.reshape(-1,1)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
hidden_nodes1 = 15
hidden_nodes2 = 10

# Add a third hidden layer
hidden_nodes3 = 5

nn_2 = tf.keras.models.Sequential()

# First hidden layer
nn_2.add(tf.keras.layers.Dense(units=hidden_nodes1,activation='relu',input_dim=input_features))

# Second hidden layer
nn_2.add(tf.keras.layers.Dense(units=hidden_nodes2,activation='sigmoid'))

# Third hidden layer
nn_2.add(tf.keras.layers.Dense(units=hidden_nodes3,activation='sigmoid'))

# Output layer
nn_2.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 15)                1005
#
#  dense_5 (Dense)             (None, 10)                160
#
#  dense_6 (Dense)             (None, 5)                 55
#
#  dense_7 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 1226 (4.79 KB)
# Trainable params: 1226 (4.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_2.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# Train the model
fit_model = nn_2.fit(X_train_scaled,y_train,epochs=25)
# Out:
# Epoch 1/25
# 157/157 [==============================] - 2s 5ms/step - loss: 0.6714 - accuracy: 0.7255
# Epoch 2/25
# 157/157 [==============================] - 1s 4ms/step - loss: 0.4495 - accuracy: 0.9936
# Epoch 3/25
# 157/157 [==============================] - 1s 4ms/step - loss: 0.2393 - accuracy: 0.9970
# Epoch 4/25
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1534 - accuracy: 0.9978
# Epoch 5/25
# 157/157 [==============================] - 1s 5ms/step - loss: 0.1099 - accuracy: 0.9980
# Epoch 6/25
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0814 - accuracy: 0.9992
# Epoch 7/25
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0632 - accuracy: 1.0000
# Epoch 8/25
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0508 - accuracy: 1.0000
# Epoch 9/25
# 157/157 [==============================] - 1s 9ms/step - loss: 0.0419 - accuracy: 1.0000
# Epoch 10/25
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 11/25
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 12/25
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 13/25
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 14/25
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 15/25
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 16/25
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 17/25
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 18/25
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 19/25
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 20/25
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 21/25
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 22/25
# 157/157 [==============================] - 1s 8ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 23/25
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 24/25
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 25/25
# 157/157 [==============================] - 1s 8ms/step - loss: 0.0059 - accuracy: 1.0000

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 53/53 - 0s - loss: 0.0204 - accuracy: 0.9970 - 331ms/epoch - 6ms/step
# Loss: 0.020389625802636147, Accuracy: 0.9970042109489441

# %%
history_df = pd.DataFrame(fit_model.history)
history_df.plot(y="loss")
plt.show()

# %%
history_df.plot(y='accuracy')
plt.show()

# %%
prediction = nn_2.predict(X_test_scaled[0].reshape(1,-1))
prediction
# Out:
# 1/1 [==============================] - 0s 112ms/step
# array([[0.00428]], dtype=float32)
